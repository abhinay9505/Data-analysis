# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\Abinay Rachakonda\\Desktop\\ai_13\\project\\note-book\\travel_dataset.csv")

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
df.shape
# Out:
# (4888, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
df["NumberOfFollowups"].unique()
# Out:
# array([ 3.,  4.,  2.,  5., nan,  1.,  6.])

# %%
df["NumberOfFollowups"]=df["NumberOfFollowups"].fillna(df["NumberOfFollowups"].mode()[0])

# %%
df["PreferredPropertyStar"]=df["PreferredPropertyStar"].fillna(df["PreferredPropertyStar"].mode()[0])

# %%
df["DurationOfPitch"]=df["DurationOfPitch"].fillna(df["DurationOfPitch"].mode()[0])

# %%
df["TypeofContact"]=df["TypeofContact"].fillna(df["TypeofContact"].mode()[0])

# %%
df["NumberOfTrips"]=df["NumberOfTrips"].fillna(df["NumberOfTrips"].mode()[0])

# %%
df["NumberOfChildrenVisiting"]=df["NumberOfChildrenVisiting"].fillna(df["NumberOfChildrenVisiting"].mode()[0])

# %%
df["Age"]=df["Age"].fillna(df["Age"].mode()[0])

# %%
df_tourisum=df.dropna(subset=["MonthlyIncome"])

# %%
df_tourisum.isnull().sum()
# Out:
# CustomerID                  0
# ProdTaken                   0
# Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# dtype: int64

# %%
df_tourisum.shape
# Out:
# (4655, 20)

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
df_tourisum['Gender'].value_counts()
# Out:
# Male       2781
# Female     1719
# Fe Male     155
# Name: Gender, dtype: int64

# %%
df_tourisum=df_tourisum.replace('Fe Male','Female')

# %%
df_tourisum["ProdTaken"]=df_tourisum['ProdTaken'].astype("object")

# %%
df_tourisum['Gender'].value_counts()
# Out:
# Male      2781
# Female    1874
# Name: Gender, dtype: int64

# %% [markdown]
# # non-Visual analysis

# %%
df_tourisum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4655 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4655 non-null   int64
#  1   ProdTaken                 4655 non-null   object
#  2   Age                       4655 non-null   float64
#  3   TypeofContact             4655 non-null   object
#  4   CityTier                  4655 non-null   int64
#  5   DurationOfPitch           4655 non-null   float64
#  6   Occupation                4655 non-null   object
#  7   Gender                    4655 non-null   object
#  8   NumberOfPersonVisiting    4655 non-null   int64
#  9   NumberOfFollowups         4655 non-null   float64
#  10  ProductPitched            4655 non-null   object
#  11  PreferredPropertyStar     4655 non-null   float64
#  12  MaritalStatus             4655 non-null   object
# ...

# %%
discrete_df = df_tourisum.select_dtypes(include=['object'])

# %%
def discrete_univariate_analysis(discrete_data):
  for col_name in discrete_data:
    print("*"*10, col_name, "*"*10)
    print(discrete_data[col_name].agg(['count', 'nunique', 'unique']))
    print('Value Counts: \n', discrete_data[col_name].value_counts())
    print()

# %%
discrete_univariate_analysis(discrete_df)
# Out:
# ********** ProdTaken **********
# count        4655
# nunique         2
# unique     [1, 0]
# Name: ProdTaken, dtype: object
# Value Counts:
#  0    3767
# 1     888
# Name: ProdTaken, dtype: int64
#
# ********** TypeofContact **********
# count                                 4655
# nunique                                  2
# unique     [Self Enquiry, Company Invited]
# Name: TypeofContact, dtype: object
# Value Counts:
#  Self Enquiry       3306
# Company Invited    1349
# Name: TypeofContact, dtype: int64
#
# ********** Occupation **********
# count                                                   4655
# nunique                                                    4
# unique     [Salaried, Free Lancer, Small Business, Large ...
# Name: Occupation, dtype: object
# Value Counts:
#  Salaried          2263
# Small Business    1970
# Large Business     420
# Free Lancer          2
# Name: Occupation, dtype: int64
#
# ********** Gender **********
# count                         4655
# ...

# %% [markdown]
# # univariate-analysis

# %%
sns.countplot(data=df_tourisum,x='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df_tourisum['Gender'].value_counts()
# Out:
# Male       2781
# Female     1719
# Fe Male     155
# Name: Gender, dtype: int64

# %%
sns.countplot(data=df_tourisum,x='MaritalStatus')
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %%
df_tourisum['MaritalStatus'].value_counts()
# Out:
# Married      2228
# Divorced      902
# Single        843
# Unmarried     682
# Name: MaritalStatus, dtype: int64

# %%
sns.countplot(data=df_tourisum,x='TypeofContact')
# Out:
# <Axes: xlabel='TypeofContact', ylabel='count'>

# %%
df_tourisum['TypeofContact'].value_counts()
# Out:
# Self Enquiry       3306
# Company Invited    1349
# Name: TypeofContact, dtype: int64

# %%
sns.countplot(data=df_tourisum,x='ProductPitched')
# Out:
# <Axes: xlabel='ProductPitched', ylabel='count'>

# %%
df_tourisum['ProductPitched'].value_counts()
# Out:
# Basic           1755
# Deluxe          1586
# Standard         742
# Super Deluxe     342
# King             230
# Name: ProductPitched, dtype: int64

# %%
sns.countplot(data=df_tourisum,x='Designation')
# Out:
# <Axes: xlabel='Designation', ylabel='count'>

# %%
df_tourisum['Designation'].value_counts()
# Out:
# Executive         1755
# Manager           1586
# Senior Manager     742
# AVP                342
# VP                 230
# Name: Designation, dtype: int64

# %%
sns.countplot(data=df_tourisum,x='Occupation')
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df_tourisum['Occupation'].value_counts()
# Out:
# Salaried          2263
# Small Business    1970
# Large Business     420
# Free Lancer          2
# Name: Occupation, dtype: int64

# %%
sns.countplot(data=df_tourisum,x='OwnCar')
# Out:
# <Axes: xlabel='OwnCar', ylabel='count'>

# %%
df_tourisum['OwnCar'].value_counts()
# Out:
# 1    2890
# 0    1765
# Name: OwnCar, dtype: int64

# %%
sns.countplot(data=df_tourisum,x='Passport')
# Out:
# <Axes: xlabel='Passport', ylabel='count'>

# %%
df_tourisum["Passport"].value_counts()
# Out:
# 0    3293
# 1    1362
# Name: Passport, dtype: int64

# %%
sns.countplot(data=df_tourisum,x='ProdTaken')
# Out:
# <Axes: xlabel='ProdTaken', ylabel='count'>

# %%
df_tourisum["ProdTaken"].value_counts()
# Out:
# 0    3767
# 1     888
# Name: ProdTaken, dtype: int64

# %%
numerical_df = df_tourisum.select_dtypes(include=['int64', 'float64'])

# %%
def numerical_univariate_analysis(numerical_data):
  for col_name in numerical_data:
    print("*"*10, col_name, "*"*10)
    print(numerical_data[col_name].agg(['min', 'max', 'mean', 'median', 'std','skew','kurt']))
    print()

# %%
numerical_univariate_analysis(numerical_df)
# Out:
# ********** CustomerID **********
# min       200000.000000
# max       204887.000000
# mean      202504.281418
# median    202560.000000
# std         1410.510246
# skew          -0.066109
# kurt          -1.192887
# Name: CustomerID, dtype: float64
#
# ********** Age **********
# min       18.000000
# max       61.000000
# mean      37.627282
# median    36.000000
# std        9.243731
# skew       0.394443
# kurt      -0.400495
# Name: Age, dtype: float64
#
# ********** CityTier **********
# min       1.000000
# max       3.000000
# mean      1.659076
# median    1.000000
# std       0.917990
# skew      0.724892
# kurt     -1.419729
# Name: CityTier, dtype: float64
#
# ********** DurationOfPitch **********
# min         5.000000
# max       127.000000
# mean       15.312567
# median     13.000000
# std         8.469468
# skew        1.809496
# kurt       12.190543
# Name: DurationOfPitch, dtype: float64
#
# ********** NumberOfPersonVisiting **********
# min       1.000000
# ...

# %%
sns.kdeplot(data=df_tourisum,x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.countplot(data=df_tourisum,x='CityTier')
# Out:
# <Axes: xlabel='CityTier', ylabel='count'>

# %%
fig, axes = plt.subplots( figsize=(10,10), constrained_layout=True)
fig.suptitle("Discrete Distribution Plot")
    
axes.set_title("count Plot")
sns.countplot(df_tourisum,x='Age', ax=axes)
plt.xticks(rotation=45)
plt.show()

# %%
fig, axes = plt.subplots( figsize=(10,10), constrained_layout=True)
fig.suptitle("Discrete Distribution Plot")
    
axes.set_title("count Plot")
sns.countplot(df_tourisum,x='DurationOfPitch', ax=axes)
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(df_tourisum,x='PitchSatisfactionScore')
# Out:
# <Axes: xlabel='PitchSatisfactionScore', ylabel='count'>

# %%
sns.countplot(df_tourisum,x='NumberOfTrips')
# Out:
# <Axes: xlabel='NumberOfTrips', ylabel='count'>

# %%
sns.countplot(df_tourisum,x='NumberOfChildrenVisiting')
# Out:
# <Axes: xlabel='NumberOfChildrenVisiting', ylabel='count'>

# %%
sns.countplot(df_tourisum,x='PreferredPropertyStar')
# Out:
# <Axes: xlabel='PreferredPropertyStar', ylabel='count'>

# %%
sns.countplot(df_tourisum,x='NumberOfPersonVisiting')
# Out:
# <Axes: xlabel='NumberOfPersonVisiting', ylabel='count'>

# %%
sns.countplot(df_tourisum,x='NumberOfFollowups')
# Out:
# <Axes: xlabel='NumberOfFollowups', ylabel='count'>

# %%
numerical_df = df_tourisum.select_dtypes(include=['int64','float64'])

# %%
discrete_univariate_analysis(numerical_df)
# Out:
# ********** CustomerID **********
# count                                                   4655
# nunique                                                 4655
# unique     [200000, 200001, 200002, 200003, 200004, 20000...
# Name: CustomerID, dtype: object
# Value Counts:
#  200000    1
# 203360    1
# 203340    1
# 203339    1
# 203338    1
#          ..
# 201719    1
# 201717    1
# 201716    1
# 201715    1
# 204887    1
# Name: CustomerID, Length: 4655, dtype: int64
#
# ********** Age **********
# count                                                   4655
# nunique                                                   44
# unique     [41.0, 49.0, 37.0, 33.0, 35.0, 32.0, 59.0, 30....
# Name: Age, dtype: object
# Value Counts:
#  35.0    323
# 36.0    230
# 34.0    204
# 30.0    199
# 31.0    195
# 32.0    193
# 33.0    185
# 37.0    181
# 38.0    174
# 29.0    172
# 41.0    154
# 39.0    150
# 28.0    144
# 40.0    139
# 42.0    137
# 27.0    130
# 43.0    130
# 46.0    121
# ...

# %% [markdown]
# # Bivariate analysis

# %%
df_clean=df_tourisum.loc[(df["MonthlyIncome"]>=20000)&(df["MonthlyIncome"]<=40000)]

# %%
sns.boxenplot(data=df_clean,x='Designation',y='MonthlyIncome')
# Out:
# <Axes: xlabel='Designation', ylabel='MonthlyIncome'>

# %%
df_clean.pivot_table(values='MonthlyIncome',
               index=['Designation'],
               aggfunc=['min','max','mean','median','std','skew'])
# Out:
#                          min           max          mean        median  \
#                MonthlyIncome MonthlyIncome MonthlyIncome MonthlyIncome
# Designation
# AVP                  21151.0       37502.0  32283.674487       32181.0
# Executive            20037.0       37868.0  21796.812227       21381.0
# Manager              20003.0       38525.0  23150.541337       23217.0
# Senior Manager       20210.0       38395.0  26707.286685       26505.5
# VP                   21195.0       38677.0  35959.131004       34999.0
#
#                          std          skew
#                MonthlyIncome MonthlyIncome
# Designation
# AVP              2752.922335     -0.485389
# Executive        1857.258673      5.493708
# Manager          2147.445102      1.333756
# Senior Manager   2699.050146      0.232632
# VP               2145.351329     -1.376718

# %%
 df_tourisum.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
sns.boxenplot(data=df_tourisum,x='OwnCar',y='Age')
# Out:
# <Axes: xlabel='OwnCar', ylabel='Age'>

# %% [markdown]
# cat  vs cat

# %%
pd.crosstab(df_tourisum['Gender'],df_tourisum['Occupation'])
# Out:
# Occupation  Free Lancer  Large Business  Salaried  Small Business
# Gender
# Fe Male               0              13        65              77
# Female                0             162       834             723
# Male                  2             245      1364            1170

# %%
tap=pd.crosstab(df_tourisum['Occupation'],df_tourisum['Gender'])

# %%
tap.plot(kind='barh',stacked=True)
# Out:
# <Axes: ylabel='Occupation'>

# %%
sns.boxplot(data=df_tourisum,y='NumberOfPersonVisiting',x='Designation')
#Value Counts: 
3    2324
2    1271
4    1025
1      32
5       3
# Out:
#   Cell In[68], line 3
#     3    2324
#     ^
# IndentationError: unexpected indent

# %%
df_tourisum.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
df_clean=df_tourisum.loc[(df["MonthlyIncome"]>=20000)&(df["MonthlyIncome"]<=40000)]

# %%
sns.boxenplot(data=df_clean,x='NumberOfPersonVisiting',y='MonthlyIncome')
# Out:
# <Axes: xlabel='NumberOfPersonVisiting', ylabel='MonthlyIncome'>

# %%
sns.boxplot(data=df_tourisum,y='NumberOfPersonVisiting',x='Occupation')
# Out:
# <Axes: xlabel='Occupation', ylabel='NumberOfPersonVisiting'>

# %%
pd.crosstab(df_tourisum['ProdTaken'],df_tourisum['ProductPitched'])
# Out:
# ProductPitched  Basic  Deluxe  King  Standard  Super Deluxe
# ProdTaken
# 0                1226    1391   210       618           322
# 1                 529     195    20       124            20

# %%
tap=pd.crosstab(df_tourisum['ProdTaken'],df_tourisum['ProductPitched'])

# %%
tap.plot(kind='barh',stacked=True)
# Out:
# <Axes: ylabel='ProdTaken'>

# %%
df_tourisum.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
pd.crosstab(df_tourisum['ProdTaken'],df_tourisum['TypeofContact'])
# Out:
# TypeofContact  Company Invited  Self Enquiry
# ProdTaken
# 0                         1051          2716
# 1                          298           590

# %%
tap=pd.crosstab(df_tourisum['ProdTaken'],df_tourisum['TypeofContact']

# %%
tap.plot(kind='barh',stacked=True)
# Out:
# <Axes: ylabel='ProdTaken'>

# %%
pd.crosstab(df_tourisum['ProdTaken'],df_tourisum['Occupation'])
# Out:
# Occupation  Free Lancer  Large Business  Salaried  Small Business
# ProdTaken
# 0                     0             303      1864            1600
# 1                     2             117       399             370

# %%
tap=pd.crosstab(df_tourisum['ProdTaken'],df_tourisum['Occupation'])

# %%
tap.plot(kind='barh',stacked=True)
# Out:
# <Axes: ylabel='ProdTaken'>

# %%
sns.boxplot(data=df_tourisum,y='NumberOfChildrenVisiting',x= 'Designation')
# Out:
# <Axes: xlabel='Designation', ylabel='NumberOfChildrenVisiting'>

# %%
df_tourisum.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
df_clean=df.loc[(df["MonthlyIncome"]>=20000)&(df["MonthlyIncome"]<=40000)]

# %%
sns.boxenplot(data=df_clean,x='ProdTaken',y='MonthlyIncome')
# Out:
# <Axes: xlabel='ProdTaken', ylabel='MonthlyIncome'>

# %%
sns.boxenplot(data=df_tourisum,y='ProdTaken',x='Designation')
# Out:
# <Axes: xlabel='Designation', ylabel='ProdTaken'>

# %%
sns.boxenplot(data=df_tourisum,y='ProdTaken',x= 'MonthlyIncome')
# Out:
# <Axes: xlabel='NumberOfPersonVisiting', ylabel='ProdTaken'>

# %%
sns.histplot(data=df_tourisum,x='ProdTaken',y='TypeofContact')
# Out:
# <Axes: xlabel='ProdTaken', ylabel='TypeofContact'>

# %%
sns.boxenplot(data=df_tourisum,y='ProdTaken',x='Occupation')
# Out:
# <Axes: xlabel='Occupation', ylabel='ProdTaken'>

# %%
df_tourisum.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
sns.histplot(data=df_tourisum,x='ProdTaken',y='Gender')
# Out:
# <Axes: xlabel='ProdTaken', ylabel='Gender'>

# %%
pd.cross(data=df_tourisum,x='ProdTaken',y='ProductPitched')
# Out:
# <Axes: xlabel='ProdTaken', ylabel='ProductPitched'>

# %%
sns.boxenplot(data=df_tourisum,x='ProdTaken',y='MaritalStatus')
# Out:
# <Axes: xlabel='ProdTaken', ylabel='MaritalStatus'>

# %%
sns.histplot(data=df_clean,x='ProdTaken',y='MonthlyIncome')
# Out:
# <Axes: xlabel='ProdTaken', ylabel='MonthlyIncome'>

# %%
sns.boxenplot(data=df_clean,y='ProdTaken',x='PreferredPropertyStar')
# Out:
# <Axes: xlabel='PreferredPropertyStar', ylabel='ProdTaken'>

# %%
fig, axs = plt.subplots( figsize=(10, 10), constrained_layout=True)
fig.suptitle("Bivariate Visualization with Seaborn")
axs.set_title("Heat Map")
sns.heatmap(df_tourisum.select_dtypes(include=['int64', 'float64']).corr(), annot=True, linewidths=0.8)

plt.show()

# %%
df_tourisum.dtypes
# Out:
# CustomerID                    int64
# ProdTaken                     int64
# Age                         float64
# TypeofContact                object
# CityTier                      int64
# DurationOfPitch             float64
# Occupation                   object
# Gender                       object
# NumberOfPersonVisiting        int64
# NumberOfFollowups           float64
# ProductPitched               object
# PreferredPropertyStar       float64
# MaritalStatus                object
# NumberOfTrips               float64
# Passport                      int64
# PitchSatisfactionScore        int64
# OwnCar                        int64
# NumberOfChildrenVisiting    float64
# Designation                  object
# MonthlyIncome               float64
# dtype: object

# %%
fig, axs = plt.subplots(figsize=(10,10)) 
axs = sns.kdeplot(df.loc[df["ProdTaken"] == 0,"MonthlyIncome"],
                color="blue", fill = True)
axs = sns.kdeplot(df.loc[df["ProdTaken"] == 1, 'MonthlyIncome'],
                ax =axs, color="red", fill= True)
axs.legend(["ProdTaken","'MonthlyIncome"],loc='upper right')
axs.set_ylabel('MonthlyIncome')
axs.set_xlabel('ProdTaken')
axs.set_title('plot')
plt.show()
